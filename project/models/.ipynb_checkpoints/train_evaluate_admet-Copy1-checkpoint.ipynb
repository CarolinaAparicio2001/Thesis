# %%
import os
import sys
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from transformers import AutoTokenizer
from sklearn.metrics import average_precision_score, roc_auc_score, f1_score

# %%
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)
    print("Torch version:", torch.__version__)
# Out:
# CUDA available: True
# CUDA device name: NVIDIA GeForce RTX 4080 SUPER
# CUDA version: 12.1
# Torch version: 2.5.1+cu121

# %%
#!pip install mmengine

# %%
#!pip install lightning-template

# %%
sys.path.append(os.path.abspath('../'))  # Adjust this path based on where your files are located
print(sys.path)

from datasets.hint.hint_admet import HINTDataset 
from datasets.ctod.ctod_enrollment import CTODataset
from mmcto.mmcto import MMCTO
from mmcto.layers.sparse_moe import SparseMOELayer, FeedForwardLayer
from mmf.early_fusion import EarlyFusion
from mmf.middle_fusion import MiddleFusion
from mmf.late_fusion import LateFusion
from torch.utils.data import Dataset
import pytorch_lightning.callbacks as pl_callbacks
# Out:
# ['C:\\Users\\Carol\\Documents\\Data Code and Deliverables\\Data Group Part\\project\\models', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\python311.zip', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\DLLs', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis', '', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib\\site-packages', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib\\site-packages\\win32', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\Carol\\Documents\\Data Code and Deliverables\\Data Group Part\\project']

# %%
PHASE = "III"
BATCH_SIZE = 16
EPOCHS = 20
LEARNING_RATE = 2e-5
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_DIM = 768

# %%
base_path = r"C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\ctod"
#base_path = r"C:/Users/Asus/Documents/Data and Code Deliverables/Data Group Part/Data/clinical-trial-outcome-prediction/Processed/ctod"
#admet_path = os.path.join(base_path, "Admet", "cooked")

data_prefix = dict(
    data_path=base_path,
    table_path=os.path.join(base_path, "text_description"),
    summarization_path=os.path.join(base_path, "brief_summary"),
    drug_description_path=os.path.join(base_path, "drugbank", "druginfo_description.json"),
    criteria_path=os.path.join(base_path, "criteria"),
    #admet_path=admet_path,
)

# %%
def move_to_device(obj, device):
    if torch.is_tensor(obj):
        return obj.to(device)
    elif isinstance(obj, dict):
        return {k: move_to_device(v, device) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [move_to_device(v, device) for v in obj]
    return obj

# %%
def build_encoder():
    return nn.TransformerEncoder(
        nn.TransformerEncoderLayer(
            d_model=MODEL_DIM,
            nhead=8,
            dim_feedforward=2048,
            dropout=0.1,
            activation='relu',
            batch_first=True
        ),
        num_layers=2
    )
input_parts = [
    "description", "criteria",
    "smiles", "smiles_concat", "smiles_summarization",
    "drugs", "drugs_concat", "drugs_summarization",
    "diseases", "diseases_concat", "diseases_summarization",
    "smiles_transformer_concat", "enrollment"
]

encoders = nn.ModuleDict({k: build_encoder() for k in input_parts})
smoe_encoder = SparseMOELayer(
    expert_cfg=FeedForwardLayer,
    num_experts=4,
    input_dim=MODEL_DIM,
    topk=2,
)

# %%
model = MMCTO(
    encoders=encoders,
    smoe_encoder=smoe_encoder,
    aux_loss=True,
    aux_loss_share_fc=False,
    moe_method="weighted",
    vocab_size=28996,
    model_dim=MODEL_DIM,
).to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
train_dataset = HINTDataset(
    data_prefix=data_prefix,
    ann_file_name=f"phase_{PHASE}_train",
    serialize_data=False,
)
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    collate_fn=train_dataset.collate_fn,
)

test_dataset = HINTDataset(
    data_prefix=data_prefix,
    ann_file_name=f"phase_{PHASE}_test",
    serialize_data=False,
)
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    collate_fn=test_dataset.collate_fn,
)
# Out:
# [Cache] Saved: C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\hint\phase_III_train_tokenized.pt
# [Cache] Saved: C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\hint\phase_III_test_tokenized.pt

# %%
train_dataset = CTODataset(
    data_prefix=data_prefix,
    ann_file_name=f"phase_{PHASE}_train",
    serialize_data=False,
)
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    collate_fn=train_dataset.collate_fn,
)

test_dataset = CTODataset(
    data_prefix=data_prefix,
    ann_file_name=f"phase_{PHASE}_valid",
    serialize_data=False,
)
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    collate_fn=test_dataset.collate_fn,
)
# Out:
# [Cache] Saved: C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\ctod\phase_III_train_tokenized.pt
# [Cache] Saved: C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\ctod\phase_III_valid_tokenized.pt

# %%
param_device = next(model.parameters()).device
print(f"[INFO] Model is on device: {param_device}")

# Confirm GPU memory usage
if torch.cuda.is_available():
    allocated = torch.cuda.memory_allocated() / 1024**2  # in MB
    reserved = torch.cuda.memory_reserved() / 1024**2    # in MB
    print(f"[INFO] GPU Memory - Allocated: {allocated:.2f} MB | Reserved: {reserved:.2f} MB")
else:
    print("[WARNING] CUDA is not available. Using CPU.")
# Out:
# [INFO] Model is on device: cuda:0
# [INFO] GPU Memory - Allocated: 671.15 MB | Reserved: 722.00 MB

# %% [markdown]
# ## HINT

# %% [markdown]
# ### PHASE I

# %%
print(f"\nTraining MMCTO on Phase {PHASE}...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase I...
#
# Epoch 1 | Avg Loss: 0.4059
# Epoch 2 | Avg Loss: 0.3871
# Epoch 3 | Avg Loss: 0.3785
# Epoch 4 | Avg Loss: 0.3657
# Epoch 5 | Avg Loss: 0.3460
# Epoch 6 | Avg Loss: 0.3151
# Epoch 7 | Avg Loss: 0.2776
# Epoch 8 | Avg Loss: 0.2365
# Epoch 9 | Avg Loss: 0.1905
# Epoch 10 | Avg Loss: 0.1432
# Epoch 11 | Avg Loss: 0.1213
# Epoch 12 | Avg Loss: 0.0948
# Epoch 13 | Avg Loss: 0.0686
# Epoch 14 | Avg Loss: 0.0526
# Epoch 15 | Avg Loss: 0.0489
# Epoch 16 | Avg Loss: 0.0445
# Epoch 17 | Avg Loss: 0.0368
# Epoch 18 | Avg Loss: 0.0381
# Epoch 19 | Avg Loss: 0.0365
# Epoch 20 | Avg Loss: 0.0208

# %%
torch.save(model.state_dict(), "mmcto_phaseI_without_llm.pth")

# %%
print(f"\nEvaluating on Phase {PHASE} Test Set...\n")
model.eval()

all_preds = {"fused": [], "target": []}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in test_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())

        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())

for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        all_preds[key] = np.array([])
# Out:
# Evaluating on Phase I Test Set...

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds and all_preds[mod].size:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# smiles                     76.04  63.12  47.95
# description                80.34  87.15  57.22
# criteria                   79.37  76.76  52.80
# enrollment                 77.49   0.00  50.00
# diseases                   67.37   3.55  33.97
# drugs                      76.29  64.25  49.67
# All (Fused)                82.04  86.12  62.39

# %% [markdown]
# ## PHASE II

# %%
print(f"\nTraining MMCTO on Phase {PHASE}...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase II...
#
# Epoch 1 | Avg Loss: 0.5056
# Epoch 2 | Avg Loss: 0.5037
# Epoch 3 | Avg Loss: 0.4968
# Epoch 4 | Avg Loss: 0.4875
# Epoch 5 | Avg Loss: 0.4746
# Epoch 6 | Avg Loss: 0.4550
# Epoch 7 | Avg Loss: 0.4306
# Epoch 8 | Avg Loss: 0.3922
# Epoch 9 | Avg Loss: 0.3527
# Epoch 10 | Avg Loss: 0.3075
# Epoch 11 | Avg Loss: 0.2544
# Epoch 12 | Avg Loss: 0.2172
# Epoch 13 | Avg Loss: 0.1807
# Epoch 14 | Avg Loss: 0.1567
# Epoch 15 | Avg Loss: 0.1381
# Epoch 16 | Avg Loss: 0.1104
# Epoch 17 | Avg Loss: 0.1102
# Epoch 18 | Avg Loss: 0.0800
# Epoch 19 | Avg Loss: 0.0824
# Epoch 20 | Avg Loss: 0.0860

# %%
torch.save(model.state_dict(), "mmcto_phaseII_without_llm.pth")

# %%
from tqdm import tqdm
print(f"\nEvaluating on Phase {PHASE} Test Set...\n")
model.eval()

all_preds = {"fused": [], "target": []}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in test_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())

        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())

for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        all_preds[key] = np.array([])
# Out:
# Evaluating on Phase II Test Set...
# C:\Users\Carol\anaconda3\envs\newthesis\Lib\site-packages\torch\nn\modules\transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\NestedTensorImpl.cpp:180.)
#   output = torch._nested_tensor_from_mask(

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds and all_preds[mod].size:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# smiles                     64.17  72.62  53.05
# description                59.29  76.34  49.59
# criteria                   61.13  70.10  49.68
# enrollment                 61.59   0.00  50.00
# diseases                   58.95  76.28  45.83
# drugs                      62.24  48.28  51.35
# All (Fused)                64.18  73.92  53.97

# %%
# def compute_metrics(preds, targets):
#     preds_binary = (preds > 0.5).astype(int)
#     pr = average_precision_score(targets, preds)
#     roc = roc_auc_score(targets, preds)
#     f1 = f1_score(targets, preds_binary)
#     return pr * 100, f1 * 100, roc * 100

# print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
# print("=" * 45)

# for mod in modalities:
#     if mod in all_preds and all_preds[mod].size:
#         pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
#         print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

# pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
# print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      59.01  71.09  47.08
# summarization              60.80  51.94  48.11
# smiles                     61.78  76.23  50.43
# description                56.69   5.82  43.49
# criteria                   60.43   0.00  47.84
# enrollment                 61.59   0.00  50.00
# diseases                   67.76  73.13  55.49
# drugs                      63.46  57.57  51.45
# All (Fused)                67.72  72.24  57.00

# %% [markdown]
# ## PHASE III

# %%
print(f"\nTraining MMCTO on Phase {PHASE} with ADMET features...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase III with ADMET features...
#
# Epoch 1 | Avg Loss: 0.4018
# Epoch 2 | Avg Loss: 0.3969
# Epoch 3 | Avg Loss: 0.3884
# Epoch 4 | Avg Loss: 0.3781
# Epoch 5 | Avg Loss: 0.3537
# Epoch 6 | Avg Loss: 0.3046
# Epoch 7 | Avg Loss: 0.2606
# Epoch 8 | Avg Loss: 0.2065
# Epoch 9 | Avg Loss: 0.1652
# Epoch 10 | Avg Loss: 0.1309
# Epoch 11 | Avg Loss: 0.0977
# Epoch 12 | Avg Loss: 0.0785
# Epoch 13 | Avg Loss: 0.0729
# Epoch 14 | Avg Loss: 0.0492
# Epoch 15 | Avg Loss: 0.0421
# Epoch 16 | Avg Loss: 0.0517
# Epoch 17 | Avg Loss: 0.0277
# Epoch 18 | Avg Loss: 0.0226
# Epoch 19 | Avg Loss: 0.0271
# Epoch 20 | Avg Loss: 0.0167

# %%
torch.save(model.state_dict(), "mmcto_phaseIII_without_llm.pth")

# %%
print(f"\nEvaluating on Phase {PHASE} Test Set...\n")
model.eval()

all_preds = {"fused": [], "target": []}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in test_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())

        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())

for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        all_preds[key] = np.array([])
# Out:
# Evaluating on Phase III Test Set...
# C:\Users\Carol\anaconda3\envs\newthesis\Lib\site-packages\torch\nn\modules\transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\NestedTensorImpl.cpp:180.)
#   output = torch._nested_tensor_from_mask(

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds and all_preds[mod].size:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# smiles                     73.76  38.40  48.94
# description                73.56  13.03  50.96
# criteria                   71.02  32.80  47.06
# enrollment                 72.56   0.00  50.00
# diseases                   77.11  72.94  54.94
# drugs                      73.41  79.47  51.95
# All (Fused)                74.49  80.97  53.89

# %%
# def compute_metrics(preds, targets):
#     preds_binary = (preds > 0.5).astype(int)
#     pr = average_precision_score(targets, preds)
#     roc = roc_auc_score(targets, preds)
#     f1 = f1_score(targets, preds_binary)
#     return pr * 100, f1 * 100, roc * 100

# print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
# print("=" * 45)

# for mod in modalities:
#     if mod in all_preds and all_preds[mod].size:
#         pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
#         print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

# pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
# print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      74.53  84.10  51.77
# summarization              70.18  51.93  46.08
# smiles                     73.69  82.81  51.25
# description                73.75  34.70  48.90
# criteria                   73.26  79.20  50.96
# enrollment                 72.56   0.00  50.00
# diseases                   76.43  81.86  54.88
# drugs                      73.30  77.36  50.76
# All (Fused)                76.07  81.19  54.92

# %% [markdown]
# # CTOD

# %% [markdown]
# ### PHASE I

# %%
print(f"\nTraining MMCTO on Phase {PHASE} with ADMET features...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase I with ADMET features...
#
# Epoch 1 | Avg Loss: 0.5985
# Epoch 2 | Avg Loss: 0.4981
# Epoch 3 | Avg Loss: 0.4925
# Epoch 4 | Avg Loss: 0.4974
# Epoch 5 | Avg Loss: 0.4850
# Epoch 6 | Avg Loss: 0.4759
# Epoch 7 | Avg Loss: 0.4586
# Epoch 8 | Avg Loss: 0.4446
# Epoch 9 | Avg Loss: 0.4150
# Epoch 10 | Avg Loss: 0.3939
# Epoch 11 | Avg Loss: 0.3527
# Epoch 12 | Avg Loss: 0.3281
# Epoch 13 | Avg Loss: 0.2948
# Epoch 14 | Avg Loss: 0.2582
# Epoch 15 | Avg Loss: 0.2339
# Epoch 16 | Avg Loss: 0.2095
# Epoch 17 | Avg Loss: 0.1935
# Epoch 18 | Avg Loss: 0.1596
# Epoch 19 | Avg Loss: 0.1616
# Epoch 20 | Avg Loss: 0.1545

# %%
torch.save(model.state_dict(), "mmcto_phaseI_CTOD_without_llm.pth")

# %%
print(f"\nEvaluating on Phase {PHASE} Valid Set...\n")
model.eval()

all_preds = {"fused": [], "target": []}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in test_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())

        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())

for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        all_preds[key] = np.array([])
# Out:
# Evaluating on Phase I Valid Set...
# C:\Users\Carol\anaconda3\envs\newthesis\Lib\site-packages\torch\nn\modules\transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\NestedTensorImpl.cpp:180.)
#   output = torch._nested_tensor_from_mask(

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds and all_preds[mod].size:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# smiles                     78.56  62.42  49.28
# description                76.97  81.70  47.73
# criteria                   78.56  62.82  50.16
# enrollment                 90.74  90.07  79.76
# diseases                   85.55  40.94  61.58
# drugs                      82.67  47.94  55.71
# All (Fused)                85.82  80.86  60.73

# %% [markdown]
# ### PHASE II

# %%
print(f"\nTraining MMCTO on Phase {PHASE} with ADMET features...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase II with ADMET features...
#
# Epoch 1 | Avg Loss: 0.7078
# Epoch 2 | Avg Loss: 0.5263
# Epoch 3 | Avg Loss: 0.4980
# Epoch 4 | Avg Loss: 0.4855
# Epoch 5 | Avg Loss: 0.4850
# Epoch 6 | Avg Loss: 0.4466
# Epoch 7 | Avg Loss: 0.4232
# Epoch 8 | Avg Loss: 0.3954
# Epoch 9 | Avg Loss: 0.3659
# Epoch 10 | Avg Loss: 0.3351
# Epoch 11 | Avg Loss: 0.3232
# Epoch 12 | Avg Loss: 0.2958
# Epoch 13 | Avg Loss: 0.2764
# Epoch 14 | Avg Loss: 0.2591
# Epoch 15 | Avg Loss: 0.2351
# Epoch 16 | Avg Loss: 0.2143
# Epoch 17 | Avg Loss: 0.2028
# Epoch 18 | Avg Loss: 0.2012
# Epoch 19 | Avg Loss: 0.2106
# Epoch 20 | Avg Loss: 0.1673

# %%
torch.save(model.state_dict(), "mmcto_phaseII_CTOD_without_llm.pth")

# %%
print(f"\nEvaluating on Phase {PHASE} Valid Set...\n")
model.eval()

all_preds = {"fused": [], "target": []}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in test_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())

        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())

for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        all_preds[key] = np.array([])
# Out:
# Evaluating on Phase II Valid Set...
# C:\Users\Carol\anaconda3\envs\newthesis\Lib\site-packages\torch\nn\modules\transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\NestedTensorImpl.cpp:180.)
#   output = torch._nested_tensor_from_mask(

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# smiles                     77.52  79.25  50.17
# description                78.53  45.68  49.79
# criteria                   78.29  87.50  51.07
# enrollment                 62.17   4.79  17.76
# diseases                   77.88  80.77  48.76
# drugs                      77.63  83.50  48.87
# All (Fused)                91.02  87.36  77.87

# %% [markdown]
# ### PHASE III

# %%
print(f"\nTraining MMCTO on Phase {PHASE}...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase III...
#
# Epoch 1 | Avg Loss: 0.5913
# Epoch 2 | Avg Loss: 0.5464
# Epoch 3 | Avg Loss: 0.4273
# Epoch 4 | Avg Loss: 0.4899
# Epoch 5 | Avg Loss: 0.5530
# Epoch 6 | Avg Loss: 0.4218
# Epoch 7 | Avg Loss: 0.3813
# Epoch 8 | Avg Loss: 0.3505
# Epoch 9 | Avg Loss: 0.3354
# Epoch 10 | Avg Loss: 0.3017
# Epoch 11 | Avg Loss: 0.2598
# Epoch 12 | Avg Loss: 0.2297
# Epoch 13 | Avg Loss: 0.2147
# Epoch 14 | Avg Loss: 0.1788
# Epoch 15 | Avg Loss: 0.1594
# Epoch 16 | Avg Loss: 0.1605
# Epoch 17 | Avg Loss: 0.1433
# Epoch 18 | Avg Loss: 0.1385
# Epoch 19 | Avg Loss: 0.1223
# Epoch 20 | Avg Loss: 0.1237

# %%
torch.save(model.state_dict(), "mmcto_phaseIII_CTOD_without_llm.pth")

# %%
from tqdm import tqdm
import numpy as np

print(f"\nEvaluating on Phase {PHASE} Valid Set...\n")
model.eval()

# Prepare prediction containers
all_preds = {
    "fused": [],
    "target": [],
}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating", leave=True):
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        # Store fused and target predictions
        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())
        else:
            print("[Warning] No fused prediction returned.")

        # Store modality-specific predictions
        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())
            else:
                print(f"[Warning] No prediction for modality: {mod}")

# Safely concatenate arrays
for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        print(f"[Warning] No data to concatenate for: {key}")
        all_preds[key] = np.array([])  # or skip if not needed
# Out:
# Evaluating on Phase III Valid Set...
# Evaluating:   0%|                                                                               | 0/33 [00:00<?, ?it/s]C:\Users\Carol\anaconda3\envs\newthesis\Lib\site-packages\torch\nn\modules\transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\NestedTensorImpl.cpp:180.)
#   output = torch._nested_tensor_from_mask(
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 33/33 [00:13<00:00,  2.46it/s]

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# smiles                     82.26   0.00  49.17
# description                85.99  47.81  58.76
# criteria                   82.89   0.92  53.99
# enrollment                 68.18   0.00  20.48
# diseases                   82.81  30.74  50.12
# drugs                      78.32  35.02  45.39
# All (Fused)                91.50  90.54  76.48

# %%
model.load_state_dict(torch.load("C:/Users/Carol/Documents/Data Code and Deliverables/Data Group Part/project/models/mmcto_phaseII.pth"))
model.eval()
model.to(DEVICE)
# Out:
# C:\Users\Carol\AppData\Local\Temp\ipykernel_15080\3584377234.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("C:/Users/Carol/Documents/Data Code and Deliverables/Data Group Part/project/models/mmcto_phaseII.pth"))
# MMCTO(
#   (encoders): ModuleDict(
#     (table): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (linear1): Linear(in_features=768, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=768, bias=True)
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (summarization): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (linear1): Linear(in_features=768, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=768, bias=True)
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (description): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (linear1): Linear(in_features=768, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=768, bias=True)
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (criteria): Sequential(
#       (0): Linear(in_features=1536, out_features=768, bias=True)
#       (1): ReLU()
#       (2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (smiles): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (linear1): Linear(in_features=768, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=768, bias=True)
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (drugs): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (linear1): Linear(in_features=768, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=768, bias=True)
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (diseases): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (linear1): Linear(in_features=768, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=768, bias=True)
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (enrollment): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (linear1): Linear(in_features=768, out_features=2048, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=2048, out_features=768, bias=True)
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (embedding): Embedding(28996, 768)
#   (smoe_encoder): SparseMOELayer(
#     (experts): ModuleList(
#       (0-3): 4 x FeedForwardLayer(
#         (linear1): Linear(in_features=768, out_features=1536, bias=True)
#         (linear2): Linear(in_features=1536, out_features=768, bias=True)
#         (act): ReLU()
#       )
#     )
#     (gate): Linear(in_features=768, out_features=4, bias=True)
#     (gate_noise): Linear(in_features=768, out_features=4, bias=True)
#     (act): Softplus(beta=1.0, threshold=20.0)
#   )
#   (smiles_transformer_encoder): ModuleDict()
#   (aux_loss_fc): ModuleDict(
#     (table): Linear(in_features=768, out_features=1, bias=True)
#     (summarization): Linear(in_features=768, out_features=1, bias=True)
#     (smiles): Linear(in_features=768, out_features=1, bias=True)
#     (description): Linear(in_features=768, out_features=1, bias=True)
#     (criteria): Linear(in_features=768, out_features=1, bias=True)
#     (enrollment): Linear(in_features=768, out_features=1, bias=True)
#     (diseases): Linear(in_features=768, out_features=1, bias=True)
#     (drugs): Linear(in_features=768, out_features=1, bias=True)
#   )
#   (scalar_proj): ModuleDict(
#     (enrollment): Linear(in_features=1, out_features=768, bias=True)
#   )
#   (gate_fc): Linear(in_features=1536, out_features=8, bias=True)
#   (final_fc): Linear(in_features=768, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (loss): BCELoss()
#   (aux_loss): BCELoss()
# )

# %%
test_dataset = HINTDataset(
    data_prefix=data_prefix,
    ann_file_name=f"phase_III_valid",  # or whatever split you want
    serialize_data=False
)
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    collate_fn=test_dataset.collate_fn,
)
# Out:
# [Cache] Saved: C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\hint\phase_III_valid_tokenized.pt

# %%
import torch
import numpy as np
import pandas as pd
from tqdm import tqdm

# 🧠 Setup — make sure model, DEVICE, test_loader are already defined
model.eval()

# 🔹 Prediction containers
all_preds = {"fused": [], "target": []}
indexes = []  # collect batch indices
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

# 🔁 Run inference
with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating"):
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]
        idxs = batch["idx"].cpu().numpy()  # <-- collect idx

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())
            indexes.append(idxs)

        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())

# ✅ Prepare for insertion
all_preds["fused"] = [np.atleast_1d(p) for p in all_preds["fused"]]
indexes = [np.atleast_1d(i) for i in indexes]
fused_preds = np.concatenate(all_preds["fused"])
indexes = np.concatenate(indexes)

# 🔒 Sanity check
assert len(fused_preds) == len(indexes), "Mismatch between predictions and indexes"

# 📂 Path to your test CSV
csv_path = r"C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\hint\phase_III_valid.csv"

# 📖 Load the CSV
df = pd.read_csv(csv_path)

# ✏️ Insert predictions into the correct rows
df.loc[indexes, "fused_pred"] = fused_preds

# 💾 Save updated CSV
df.to_csv(csv_path, index=False)
print(f"✅ Added {len(fused_preds)} predictions to CSV:\n{csv_path}")
# Out:
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 43/43 [00:19<00:00,  2.22it/s]
# ✅ Added 676 predictions to CSV:
# C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\hint\phase_III_valid.csv
