# %%
import os
import sys
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from transformers import AutoTokenizer
from sklearn.metrics import average_precision_score, roc_auc_score, f1_score

# %%
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA device name:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)
    print("Torch version:", torch.__version__)
# Out:
# CUDA available: True
# CUDA device name: NVIDIA GeForce RTX 4080 SUPER
# CUDA version: 12.1
# Torch version: 2.5.1+cu121

# %%
#!pip install mmengine

# %%
#!pip install lightning-template

# %%
sys.path.append(os.path.abspath('../'))  # Adjust this path based on where your files are located
print(sys.path)

from datasets.hint.hint import HINTDataset 
from datasets.ctod.ctod_enrollment import CTODataset
from mmcto.mmcto import MMCTO
from mmcto.layers.sparse_moe import SparseMOELayer, FeedForwardLayer
from mmf.early_fusion import EarlyFusion
from mmf.middle_fusion import MiddleFusion
from mmf.late_fusion import LateFusion
from torch.utils.data import Dataset
import pytorch_lightning.callbacks as pl_callbacks
# Out:
# ['C:\\Users\\Carol\\Documents\\Data Code and Deliverables\\Data Group Part\\project\\models', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\python311.zip', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\DLLs', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis', '', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib\\site-packages', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib\\site-packages\\win32', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\Carol\\anaconda3\\envs\\newthesis\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\Carol\\Documents\\Data Code and Deliverables\\Data Group Part\\project']

# %%
PHASE = "I"
BATCH_SIZE = 16
EPOCHS = 20
LEARNING_RATE = 2e-5
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_DIM = 768

# %%
base_path = r"C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\ctod"
#base_path = r"C:/Users/Asus/Documents/Data and Code Deliverables/Data Group Part/Data/clinical-trial-outcome-prediction/Processed/hint"
data_prefix = dict(
    data_path=base_path,
    table_path=os.path.join(base_path, "text_description"),
    summarization_path=os.path.join(base_path, "brief_summary"),
    drug_description_path=os.path.join(base_path, "drugbank", "druginfo_description.json"),
    criteria_path=os.path.join(base_path, "criteria"),
)

# %%
def move_to_device(obj, device):
    if torch.is_tensor(obj):
        return obj.to(device)
    elif isinstance(obj, dict):
        return {k: move_to_device(v, device) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [move_to_device(v, device) for v in obj]
    return obj

# %%
def build_encoder():
    return nn.TransformerEncoder(
        nn.TransformerEncoderLayer(
            d_model=MODEL_DIM,
            nhead=8,
            dim_feedforward=2048,
            dropout=0.1,
            activation='relu',
            batch_first=True
        ),
        num_layers=2
    )

input_parts = [
    "table", "summarization", "description", "criteria",
    "smiles", "smiles_concat", "smiles_summarization",
    "drugs", "drugs_concat", "drugs_summarization",
    "diseases", "diseases_concat", "diseases_summarization",
    "smiles_transformer_concat", "enrollment"
]

encoders = nn.ModuleDict({k: build_encoder() for k in input_parts})
smoe_encoder = SparseMOELayer(
    expert_cfg=FeedForwardLayer,
    num_experts=4,
    input_dim=MODEL_DIM,
    topk=2,
)

# %%
model = MMCTO(
    encoders=encoders,
    smoe_encoder=smoe_encoder,
    aux_loss=True,
    aux_loss_share_fc=False,
    moe_method="weighted",
    vocab_size=28996,
    model_dim=MODEL_DIM,
).to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
# train_dataset = HINTDataset(
#     data_prefix=data_prefix,
#     ann_file_name=f"phase_{PHASE}_train",
#     serialize_data=False,
# )
# train_loader = DataLoader(
#     train_dataset,
#     batch_size=BATCH_SIZE,
#     shuffle=True,
#     collate_fn=train_dataset.collate_fn,
# )

# test_dataset = HINTDataset(
#     data_prefix=data_prefix,
#     ann_file_name=f"phase_{PHASE}_test",
#     serialize_data=False,
# )
# test_loader = DataLoader(
#     test_dataset,
#     batch_size=BATCH_SIZE,
#     shuffle=False,
#     collate_fn=test_dataset.collate_fn,
# )

# %%
train_dataset = CTODataset(
    data_prefix=data_prefix,
    ann_file_name=f"phase_{PHASE}_train",
    serialize_data=False,
)
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    collate_fn=train_dataset.collate_fn,
)

test_dataset = CTODataset(
    data_prefix=data_prefix,
    ann_file_name=f"phase_{PHASE}_valid",
    serialize_data=False,
)
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    collate_fn=test_dataset.collate_fn,
)
# Out:
# [Cache] Saved: C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\ctod\phase_I_train_tokenized.pt
# [Cache] Saved: C:\Users\Carol\Documents\Data Code and Deliverables\Data Group Part\Data\clinical-trial-outcome-prediction\Processed\ctod\phase_I_valid_tokenized.pt

# %%
param_device = next(model.parameters()).device
print(f"[INFO] Model is on device: {param_device}")

# Confirm GPU memory usage
if torch.cuda.is_available():
    allocated = torch.cuda.memory_allocated() / 1024**2  # in MB
    reserved = torch.cuda.memory_reserved() / 1024**2    # in MB
    print(f"[INFO] GPU Memory - Allocated: {allocated:.2f} MB | Reserved: {reserved:.2f} MB")
else:
    print("[WARNING] CUDA is not available. Using CPU.")
# Out:
# [INFO] Model is on device: cuda:0
# [INFO] GPU Memory - Allocated: 671.15 MB | Reserved: 722.00 MB

# %% [markdown]
# ## HINT

# %% [markdown]
# ### PHASE I

# %%
# print(f"\nTraining MMCTO on Phase {PHASE}...\n")
# model.train()
# for epoch in range(EPOCHS):
#     running_loss = 0.0
#     for batch in train_loader:
#         batch = move_to_device(batch, DEVICE)
#         out = model(batch)
#         loss = out["loss_dict"]["loss"]

#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()

#     avg_loss = running_loss / len(train_loader)
#     print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase I...
#
# Epoch 1 | Avg Loss: 0.4119
# Epoch 2 | Avg Loss: 0.3912
# Epoch 3 | Avg Loss: 0.3787
# Epoch 4 | Avg Loss: 0.3690
# Epoch 5 | Avg Loss: 0.3512
# Epoch 6 | Avg Loss: 0.3179
# Epoch 7 | Avg Loss: 0.2733
# Epoch 8 | Avg Loss: 0.2167
# Epoch 9 | Avg Loss: 0.1658
# Epoch 10 | Avg Loss: 0.1207
# Epoch 11 | Avg Loss: 0.0912
# Epoch 12 | Avg Loss: 0.0516
# Epoch 13 | Avg Loss: 0.0524
# Epoch 14 | Avg Loss: 0.0247
# Epoch 15 | Avg Loss: 0.0468
# Epoch 16 | Avg Loss: 0.0209
# Epoch 17 | Avg Loss: 0.0213
# Epoch 18 | Avg Loss: 0.0212
# Epoch 19 | Avg Loss: 0.0134
# Epoch 20 | Avg Loss: 0.0129

# %%
# torch.save(model.state_dict(), "mmcto_phaseI.pth")

# %%
# from tqdm import tqdm
# import numpy as np

# print(f"\nEvaluating on Phase {PHASE} Test Set...\n")
# model.eval()

# # Prepare prediction containers
# all_preds = {
#     "fused": [],
#     "target": [],
# }
# modalities = model.final_input_parts
# for mod in modalities:
#     all_preds[mod] = []

# with torch.no_grad():
#     for batch in tqdm(test_loader, desc="Evaluating", leave=True):
#         batch = move_to_device(batch, DEVICE)
#         out = model(batch)

#         # Store fused and target predictions
#         fused_preds = out["metric_dict"].get("preds")
#         target = batch["label"]

#         if fused_preds is not None:
#             all_preds["fused"].append(fused_preds.cpu().numpy())
#             all_preds["target"].append(target.cpu().numpy())
#         else:
#             print("[Warning] No fused prediction returned.")

#         # Store modality-specific predictions
#         for mod in modalities:
#             mod_pred = out["metric_dict"].get(mod)
#             if mod_pred is not None:
#                 all_preds[mod].append(mod_pred.cpu().numpy())
#             else:
#                 print(f"[Warning] No prediction for modality: {mod}")

# # Safely concatenate arrays
# for key in all_preds:
#     if all_preds[key]:
#         all_preds[key] = np.concatenate(all_preds[key])
#     else:
#         print(f"[Warning] No data to concatenate for: {key}")
#         all_preds[key] = np.array([])  # or skip if not needed
# Out:
# Evaluating on Phase I Test Set...
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 57/57 [00:29<00:00,  1.95it/s]

# %%
# def compute_metrics(preds, targets):
#     preds_binary = (preds > 0.5).astype(int)
#     pr = average_precision_score(targets, preds)
#     roc = roc_auc_score(targets, preds)
#     f1 = f1_score(targets, preds_binary)
#     return pr * 100, f1 * 100, roc * 100

# print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
# print("=" * 45)

# for mod in modalities:
#     if mod in all_preds:
#         pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
#         print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

# pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
# print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      80.30   3.91  56.94
# summarization              71.55   8.95  39.45
# smiles                     78.36  54.91  48.81
# description                79.97  85.35  56.99
# criteria                   77.07   0.00  49.57
# All (Fused)                84.82  86.26  65.68

# %% [markdown]
# ## PHASE II

# %%
print(f"\nTraining MMCTO on Phase {PHASE}...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase II...
#
# Epoch 1 | Avg Loss: 0.5089
# Epoch 2 | Avg Loss: 0.5024
# Epoch 3 | Avg Loss: 0.4984
# Epoch 4 | Avg Loss: 0.4946
# Epoch 5 | Avg Loss: 0.4891
# Epoch 6 | Avg Loss: 0.4725
# Epoch 7 | Avg Loss: 0.4479
# Epoch 8 | Avg Loss: 0.4149
# Epoch 9 | Avg Loss: 0.3455
# Epoch 10 | Avg Loss: 0.2896
# Epoch 11 | Avg Loss: 0.2302
# Epoch 12 | Avg Loss: 0.1738
# Epoch 13 | Avg Loss: 0.1275
# Epoch 14 | Avg Loss: 0.1058
# Epoch 15 | Avg Loss: 0.0866
# Epoch 16 | Avg Loss: 0.0705
# Epoch 17 | Avg Loss: 0.0566
# Epoch 18 | Avg Loss: 0.0753
# Epoch 19 | Avg Loss: 0.0471
# Epoch 20 | Avg Loss: 0.0364

# %%
# torch.save(model.state_dict(), "mmcto_phaseII.pth")

# %%
# from tqdm import tqdm
# import numpy as np

# print(f"\nEvaluating on Phase {PHASE} Test Set...\n")
# model.eval()

# # Prepare prediction containers
# all_preds = {
#     "fused": [],
#     "target": [],
# }
# modalities = model.final_input_parts
# for mod in modalities:
#     all_preds[mod] = []

# with torch.no_grad():
#     for batch in tqdm(test_loader, desc="Evaluating", leave=True):
#         batch = move_to_device(batch, DEVICE)
#         out = model(batch)

#         # Store fused and target predictions
#         fused_preds = out["metric_dict"].get("preds")
#         target = batch["label"]

#         if fused_preds is not None:
#             all_preds["fused"].append(fused_preds.cpu().numpy())
#             all_preds["target"].append(target.cpu().numpy())
#         else:
#             print("[Warning] No fused prediction returned.")

#         # Store modality-specific predictions
#         for mod in modalities:
#             mod_pred = out["metric_dict"].get(mod)
#             if mod_pred is not None:
#                 all_preds[mod].append(mod_pred.cpu().numpy())
#             else:
#                 print(f"[Warning] No prediction for modality: {mod}")

# # Safely concatenate arrays
# for key in all_preds:
#     if all_preds[key]:
#         all_preds[key] = np.concatenate(all_preds[key])
#     else:
#         print(f"[Warning] No data to concatenate for: {key}")
#         all_preds[key] = np.array([])  # or skip if not needed
# Out:
# Evaluating on Phase II Test Set...
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:35<00:00,  1.93it/s]

# %%
# def compute_metrics(preds, targets):
#     preds_binary = (preds > 0.5).astype(int)
#     pr = average_precision_score(targets, preds)
#     roc = roc_auc_score(targets, preds)
#     f1 = f1_score(targets, preds_binary)
#     return pr * 100, f1 * 100, roc * 100

# print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
# print("=" * 45)

# for mod in modalities:
#     if mod in all_preds:
#         pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
#         print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

# pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
# print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      63.59  74.51  52.06
# summarization              64.66  65.51  55.59
# smiles                     61.38  75.06  48.65
# description                58.62  75.47  48.11
# criteria                   61.49  39.44  48.78
# All (Fused)                63.92  73.39  53.52

# %% [markdown]
# ## PHASE III

# %%
# print(f"\nTraining MMCTO on Phase {PHASE}...\n")
# model.train()
# for epoch in range(EPOCHS):
#     running_loss = 0.0
#     for batch in train_loader:
#         batch = move_to_device(batch, DEVICE)
#         out = model(batch)
#         loss = out["loss_dict"]["loss"]

#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()

#     avg_loss = running_loss / len(train_loader)
#     print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase III...
#
# Epoch 1 | Avg Loss: 0.3996
# Epoch 2 | Avg Loss: 0.3976
# Epoch 3 | Avg Loss: 0.3937
# Epoch 4 | Avg Loss: 0.3906
# Epoch 5 | Avg Loss: 0.3720
# Epoch 6 | Avg Loss: 0.3531
# Epoch 7 | Avg Loss: 0.3141
# Epoch 8 | Avg Loss: 0.2731
# Epoch 9 | Avg Loss: 0.2326
# Epoch 10 | Avg Loss: 0.1798
# Epoch 11 | Avg Loss: 0.1211
# Epoch 12 | Avg Loss: 0.0984
# Epoch 13 | Avg Loss: 0.0646
# Epoch 14 | Avg Loss: 0.0493
# Epoch 15 | Avg Loss: 0.0363
# Epoch 16 | Avg Loss: 0.0229
# Epoch 17 | Avg Loss: 0.0270
# Epoch 18 | Avg Loss: 0.0251
# Epoch 19 | Avg Loss: 0.0348
# Epoch 20 | Avg Loss: 0.0408

# %%
#torch.save(model.state_dict(), "mmcto_phaseIII.pth")

# %%
# from tqdm import tqdm
# import numpy as np

# print(f"\nEvaluating on Phase {PHASE} Test Set...\n")
# model.eval()

# # Prepare prediction containers
# all_preds = {
#     "fused": [],
#     "target": [],
# }
# modalities = model.final_input_parts
# for mod in modalities:
#     all_preds[mod] = []

# with torch.no_grad():
#     for batch in tqdm(test_loader, desc="Evaluating", leave=True):
#         batch = move_to_device(batch, DEVICE)
#         out = model(batch)

#         # Store fused and target predictions
#         fused_preds = out["metric_dict"].get("preds")
#         target = batch["label"]

#         if fused_preds is not None:
#             all_preds["fused"].append(fused_preds.cpu().numpy())
#             all_preds["target"].append(target.cpu().numpy())
#         else:
#             print("[Warning] No fused prediction returned.")

#         # Store modality-specific predictions
#         for mod in modalities:
#             mod_pred = out["metric_dict"].get(mod)
#             if mod_pred is not None:
#                 all_preds[mod].append(mod_pred.cpu().numpy())
#             else:
#                 print(f"[Warning] No prediction for modality: {mod}")

# # Safely concatenate arrays
# for key in all_preds:
#     if all_preds[key]:
#         all_preds[key] = np.concatenate(all_preds[key])
#     else:
#         print(f"[Warning] No data to concatenate for: {key}")
#         all_preds[key] = np.array([])  # or skip if not needed
# Out:
# Evaluating on Phase III Test Set...
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 41/41 [00:21<00:00,  1.95it/s]

# %%
# def compute_metrics(preds, targets):
#     preds_binary = (preds > 0.5).astype(int)
#     pr = average_precision_score(targets, preds)
#     roc = roc_auc_score(targets, preds)
#     f1 = f1_score(targets, preds_binary)
#     return pr * 100, f1 * 100, roc * 100

# print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
# print("=" * 45)

# for mod in modalities:
#     if mod in all_preds:
#         pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
#         print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

# pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
# print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      74.05  33.99  50.88
# summarization              72.09   8.33  47.20
# smiles                     71.11  84.10  47.92
# description                75.76  22.38  54.32
# criteria                   70.44  79.35  47.85
# All (Fused)                74.98  79.34  55.18

# %% [markdown]
# # CTOD

# %% [markdown]
# ### PHASE I

# %%
print(f"\nTraining MMCTO on Phase {PHASE}...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase I...
#
# Epoch 1 | Avg Loss: 0.5072
# Epoch 2 | Avg Loss: 0.5221
# Epoch 3 | Avg Loss: 0.5056
# Epoch 4 | Avg Loss: 0.4657
# Epoch 5 | Avg Loss: 0.4466
# Epoch 6 | Avg Loss: 0.4231
# Epoch 7 | Avg Loss: 0.4039
# Epoch 8 | Avg Loss: 0.3717
# Epoch 9 | Avg Loss: 0.3504
# Epoch 10 | Avg Loss: 0.3217
# Epoch 11 | Avg Loss: 0.3020
# Epoch 12 | Avg Loss: 0.2675
# Epoch 13 | Avg Loss: 0.2313
# Epoch 14 | Avg Loss: 0.2094
# Epoch 15 | Avg Loss: 0.1760
# Epoch 16 | Avg Loss: 0.1588
# Epoch 17 | Avg Loss: 0.1220
# Epoch 18 | Avg Loss: 0.1282
# Epoch 19 | Avg Loss: 0.0955
# Epoch 20 | Avg Loss: 0.0758

# %%
torch.save(model.state_dict(), "mmcto_phaseI_CTOD.pth")

# %%
from tqdm import tqdm
import numpy as np

print(f"\nEvaluating on Phase {PHASE} Valid Set...\n")
model.eval()

# Prepare prediction containers
all_preds = {
    "fused": [],
    "target": [],
}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating", leave=True):
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        # Store fused and target predictions
        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())
        else:
            print("[Warning] No fused prediction returned.")

        # Store modality-specific predictions
        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())
            else:
                print(f"[Warning] No prediction for modality: {mod}")

# Safely concatenate arrays
for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        print(f"[Warning] No data to concatenate for: {key}")
        all_preds[key] = np.array([])  # or skip if not needed
# Out:
# Evaluating on Phase I Valid Set...
# Evaluating:   0%|                                                                               | 0/32 [00:00<?, ?it/s]C:\Users\Carol\anaconda3\envs\newthesis\Lib\site-packages\torch\nn\modules\transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\NestedTensorImpl.cpp:180.)
#   output = torch._nested_tensor_from_mask(
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 32/32 [00:16<00:00,  1.96it/s]

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      81.38  30.39  57.09
# summarization              76.35  59.25  45.38
# smiles                     79.74  88.20  51.58
# description                81.35  82.73  54.68
# criteria                   80.18  38.61  50.01
# enrollment                 64.03   0.00  20.52
# diseases                   83.12  85.84  53.25
# drugs                      75.68  59.45  44.65
# All (Fused)                89.57  86.25  73.47

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      80.27  11.37  50.42
# summarization              87.85  82.09  65.03
# smiles                     78.71  13.49  47.19
# description                80.73  69.15  52.23
# criteria                   82.03  39.00  53.43
# All (Fused)                87.41  82.34  64.59

# %% [markdown]
# ### PHASE II

# %%
print(f"\nTraining MMCTO on Phase {PHASE}...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase II...
#
# Epoch 1 | Avg Loss: 0.5416
# Epoch 2 | Avg Loss: 0.5401
# Epoch 3 | Avg Loss: 0.5352
# Epoch 4 | Avg Loss: 0.5305
# Epoch 5 | Avg Loss: 0.5263
# Epoch 6 | Avg Loss: 0.5126
# Epoch 7 | Avg Loss: 0.4932
# Epoch 8 | Avg Loss: 0.4608
# Epoch 9 | Avg Loss: 0.4260
# Epoch 10 | Avg Loss: 0.3818
# Epoch 11 | Avg Loss: 0.3453
# Epoch 12 | Avg Loss: 0.2917
# Epoch 13 | Avg Loss: 0.2461
# Epoch 14 | Avg Loss: 0.2003
# Epoch 15 | Avg Loss: 0.1612
# Epoch 16 | Avg Loss: 0.1295
# Epoch 17 | Avg Loss: 0.0940
# Epoch 18 | Avg Loss: 0.0761
# Epoch 19 | Avg Loss: 0.0770
# Epoch 20 | Avg Loss: 0.0600

# %%
torch.save(model.state_dict(), "mmcto_phaseII_CTOD.pth")

# %%
from tqdm import tqdm
import numpy as np

print(f"\nEvaluating on Phase {PHASE} Valid Set...\n")
model.eval()

# Prepare prediction containers
all_preds = {
    "fused": [],
    "target": [],
}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating", leave=True):
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        # Store fused and target predictions
        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())
        else:
            print("[Warning] No fused prediction returned.")

        # Store modality-specific predictions
        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())
            else:
                print(f"[Warning] No prediction for modality: {mod}")

# Safely concatenate arrays
for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        print(f"[Warning] No data to concatenate for: {key}")
        all_preds[key] = np.array([])  # or skip if not needed
# Out:
# Evaluating on Phase II Valid Set...
# Evaluating:   0%|                                                                               | 0/54 [00:00<?, ?it/s]C:\Users\Carol\anaconda3\envs\newthesis\Lib\site-packages\torch\nn\modules\transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\NestedTensorImpl.cpp:180.)
#   output = torch._nested_tensor_from_mask(
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 54/54 [00:26<00:00,  2.02it/s]

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      75.90  48.09  44.34
# summarization              76.80  83.83  48.64
# smiles                     77.50  87.57  48.77
# description                78.60  78.31  51.52
# criteria                   76.72   0.60  47.17
# All (Fused)                79.84  80.58  53.71

# %% [markdown]
# ### PHASE III

# %%
print(f"\nTraining MMCTO on Phase {PHASE}...\n")
model.train()
for epoch in range(EPOCHS):
    running_loss = 0.0
    for batch in train_loader:
        batch = move_to_device(batch, DEVICE)
        out = model(batch)
        loss = out["loss_dict"]["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1} | Avg Loss: {avg_loss:.4f}")
# Out:
# Training MMCTO on Phase III...
#
# Epoch 1 | Avg Loss: 0.4446
# Epoch 2 | Avg Loss: 0.4305
# Epoch 3 | Avg Loss: 0.4317
# Epoch 4 | Avg Loss: 0.4282
# Epoch 5 | Avg Loss: 0.4142
# Epoch 6 | Avg Loss: 0.4092
# Epoch 7 | Avg Loss: 0.3951
# Epoch 8 | Avg Loss: 0.3848
# Epoch 9 | Avg Loss: 0.3691
# Epoch 10 | Avg Loss: 0.3359
# Epoch 11 | Avg Loss: 0.2921
# Epoch 12 | Avg Loss: 0.2487
# Epoch 13 | Avg Loss: 0.2002
# Epoch 14 | Avg Loss: 0.1481
# Epoch 15 | Avg Loss: 0.1147
# Epoch 16 | Avg Loss: 0.0864
# Epoch 17 | Avg Loss: 0.0805
# Epoch 18 | Avg Loss: 0.0665
# Epoch 19 | Avg Loss: 0.0555
# Epoch 20 | Avg Loss: 0.0445

# %%
torch.save(model.state_dict(), "mmcto_phaseIII_CTOD.pth")

# %%
from tqdm import tqdm
import numpy as np

print(f"\nEvaluating on Phase {PHASE} Valid Set...\n")
model.eval()

# Prepare prediction containers
all_preds = {
    "fused": [],
    "target": [],
}
modalities = model.final_input_parts
for mod in modalities:
    all_preds[mod] = []

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Evaluating", leave=True):
        batch = move_to_device(batch, DEVICE)
        out = model(batch)

        # Store fused and target predictions
        fused_preds = out["metric_dict"].get("preds")
        target = batch["label"]

        if fused_preds is not None:
            all_preds["fused"].append(fused_preds.cpu().numpy())
            all_preds["target"].append(target.cpu().numpy())
        else:
            print("[Warning] No fused prediction returned.")

        # Store modality-specific predictions
        for mod in modalities:
            mod_pred = out["metric_dict"].get(mod)
            if mod_pred is not None:
                all_preds[mod].append(mod_pred.cpu().numpy())
            else:
                print(f"[Warning] No prediction for modality: {mod}")

# Safely concatenate arrays
for key in all_preds:
    if all_preds[key]:
        all_preds[key] = np.concatenate(all_preds[key])
    else:
        print(f"[Warning] No data to concatenate for: {key}")
        all_preds[key] = np.array([])  # or skip if not needed
# Out:
# Evaluating on Phase III Valid Set...
# Evaluating:   0%|                                                                               | 0/33 [00:00<?, ?it/s]C:\Users\Carol\anaconda3\envs\newthesis\Lib\site-packages\torch\nn\modules\transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\NestedTensorImpl.cpp:180.)
#   output = torch._nested_tensor_from_mask(
# Evaluating: 100%|██████████████████████████████████████████████████████████████████████| 33/33 [00:15<00:00,  2.09it/s]

# %%
def compute_metrics(preds, targets):
    preds_binary = (preds > 0.5).astype(int)
    pr = average_precision_score(targets, preds)
    roc = roc_auc_score(targets, preds)
    f1 = f1_score(targets, preds_binary)
    return pr * 100, f1 * 100, roc * 100

print(f"{'Modality':<25} {'PR':>6} {'F1':>6} {'ROC':>6}")
print("=" * 45)

for mod in modalities:
    if mod in all_preds:
        pr, f1, roc = compute_metrics(all_preds[mod], all_preds["target"])
        print(f"{mod:<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")

pr, f1, roc = compute_metrics(all_preds["fused"], all_preds["target"])
print(f"{'All (Fused)':<25} {pr:6.2f} {f1:6.2f} {roc:6.2f}")
# Out:
# Modality                      PR     F1    ROC
# =============================================
# table                      80.32  49.60  44.98
# summarization              84.61  50.57  52.59
# smiles                     78.70   6.65  43.64
# description                83.49  86.00  52.69
# criteria                   82.26  37.92  47.52
# All (Fused)                84.15  82.86  56.14
