# %%
#!pip install nbimporter
import os

# List all your notebook files
notebooks = [
    'mmcto.ipynb',
]

# Convert all notebooks to .py files
for notebook in notebooks:
    os.system(f"jupyter nbconvert --to python {notebook}")
